# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
first_dataset=pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
second_dataset=pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
first_dataset
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# 0        JC Buttler        NaN            0           0          0
# 1        JC Buttler    legbyes            0           1          1
# 2       YBK Jaiswal        NaN            1           0          1
# 3        JC Buttler        NaN            0           0          0
# 4        JC Buttler        NaN            0           0          0
# ...             ...        ...          ...         ...        ...
# 225949     SB Joshi    legbyes            0           1          1
# 225950      P Kumar        NaN            1           0          1
# 225951     SB Joshi        NaN            0           0          0
# 225952      P Kumar      wides            0           1          1
# 225953      P Kumar        NaN            0           0          0
#
#         non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# 0                  0                 0        NaN     NaN               NaN
# 1                  0                 0        NaN     NaN               NaN
# 2                  0                 0        NaN     NaN               NaN
# 3                  0                 0        NaN     NaN               NaN
# 4                  0                 0        NaN     NaN               NaN
# ...              ...               ...        ...     ...               ...
# 225949             0                 0        NaN     NaN               NaN
# 225950             0                 0        NaN     NaN               NaN
# 225951             0                 0        NaN     NaN               NaN
# 225952             0                 0        NaN     NaN               NaN
# 225953             0                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [225954 rows x 17 columns]

# %%
second_dataset
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0            bat         N               Gujarat Titans  Wickets     7.0
# 1          field         N             Rajasthan Royals  Wickets     7.0
# 2          field         N  Royal Challengers Bangalore     Runs    14.0
# 3          field         N               Gujarat Titans  Wickets     7.0
# 4            bat         N                 Punjab Kings  Wickets     5.0
# ..           ...       ...                          ...      ...     ...
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 0      NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]

# %%
first_dataset.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
total_runs = first_dataset.groupby(['ID','innings']).sum()['total_run'].add(1).reset_index()

# %%
total_runs
# Out:
#            ID  innings  total_run
# 0      335982        1        223
# 1      335982        2         83
# 2      335983        1        241
# 3      335983        2        208
# 4      335984        1        130
# ...       ...      ...        ...
# 1923  1312198        2        194
# 1924  1312199        1        158
# 1925  1312199        2        162
# 1926  1312200        1        131
# 1927  1312200        2        134
#
# [1928 rows x 3 columns]

# %%
total_runs = total_runs[total_runs['innings']==1]

# %%
match_df=second_dataset.merge(total_runs[['ID','total_run']],left_on='ID',right_on='ID')

# %%
match_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...                  WinningTeam    WonBy Margin  method  \
# 0            bat  ...               Gujarat Titans  Wickets    7.0     NaN
# 1          field  ...             Rajasthan Royals  Wickets    7.0     NaN
# 2          field  ...  Royal Challengers Bangalore     Runs   14.0     NaN
# 3          field  ...               Gujarat Titans  Wickets    7.0     NaN
# 4            bat  ...                 Punjab Kings  Wickets    5.0     NaN
# ..           ...  ...                          ...      ...    ...     ...
# 945          bat  ...        Kolkata Knight Riders  Wickets    5.0     NaN
# 946          bat  ...  Royal Challengers Bangalore  Wickets    5.0     NaN
# 947          bat  ...             Delhi Daredevils  Wickets    9.0     NaN
# 948          bat  ...          Chennai Super Kings     Runs   33.0     NaN
# 949        field  ...        Kolkata Knight Riders     Runs  140.0     NaN
#
#     Player_of_Match                                       Team1Players  \
# 0         HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1        JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2        RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3         DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4     Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..              ...                                                ...
# 945       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 total_run
# 0       Nitin Menon       131
# 1       Nitin Menon       158
# 2          MA Gough       208
# 3         VK Sharma       189
# 4     NA Patwardhan       158
# ..              ...       ...
# 945     K Hariharan       111
# 946       DJ Harper       166
# 947  GA Pratapkumar       130
# 948      SL Shastri       241
# 949     RE Koertzen       223
#
# [950 rows x 21 columns]

# %%
match_df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
match_df['Team1'] = match_df['Team1'].replace('Delhi Daredevils','Delhi Capitals')
match_df['Team2'] = match_df['Team2'].replace('Delhi Daredevils','Delhi Capitals')

match_df['Team1'] = match_df['Team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['Team2'] = match_df['Team2'].replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['Team1'] = match_df['Team1'].replace('Kings XI Punjab','Punjab Kings')
match_df['Team2'] = match_df['Team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
match_df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Delhi Capitals                 114
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Sunrisers Hyderabad            108
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Pune Warriors                   23
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
teams = ['Kolkata Knight Riders',
         'Chennai Super Kings',
         'Punjab Kings',
         'Rajasthan Royals',
         'Mumbai Indians',
         'Delhi Capitals',
         'Royal Challengers Bangalore',
         'Sunrisers Hyderabad',
         'Lucknow Super Giants',
         'Gujarat Titans'
         ]
match_df = match_df[match_df['Team1'].isin(teams)]
match_df = match_df[match_df['Team2'].isin(teams)]

# %%
match_df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    118
# Chennai Super Kings            107
# Delhi Capitals                 106
# Punjab Kings                   103
# Mumbai Indians                 102
# Sunrisers Hyderabad            101
# Kolkata Knight Riders           98
# Rajasthan Royals                85
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Name: count, dtype: int64

# %%
match_df.shape
# Out:
# (835, 21)

# %%
match_df = match_df[['ID','City','WinningTeam','total_run', 'Team1', 'Team2']]

# %%
second_innings = match_df.merge(first_dataset,on='ID')
second_innings
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 0       1312200  Ahmedabad         Gujarat Titans          131
# 1       1312200  Ahmedabad         Gujarat Titans          131
# 2       1312200  Ahmedabad         Gujarat Titans          131
# 3       1312200  Ahmedabad         Gujarat Titans          131
# 4       1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 198930   335982  Bangalore  Kolkata Knight Riders          223
# 198931   335982  Bangalore  Kolkata Knight Riders          223
# 198932   335982  Bangalore  Kolkata Knight Riders          223
# 198933   335982  Bangalore  Kolkata Knight Riders          223
# 198934   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 0                  Rajasthan Royals         Gujarat Titans        1      0
# 1                  Rajasthan Royals         Gujarat Titans        1      0
# 2                  Rajasthan Royals         Gujarat Titans        1      0
# 3                  Rajasthan Royals         Gujarat Titans        1      0
# 4                  Rajasthan Royals         Gujarat Titans        1      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber       batter  ... extra_type batsman_run extras_run  \
# 0                1  YBK Jaiswal  ...        NaN           0          0
# 1                2  YBK Jaiswal  ...    legbyes           0          1
# 2                3   JC Buttler  ...        NaN           1          0
# 3                4  YBK Jaiswal  ...        NaN           0          0
# 4                5  YBK Jaiswal  ...        NaN           0          0
# ...            ...          ...  ...        ...         ...        ...
# 198930           5      P Kumar  ...    legbyes           0          1
# 198931           6     SB Joshi  ...        NaN           1          0
# 198932           7      P Kumar  ...        NaN           0          0
# 198933           1     SB Joshi  ...      wides           0          1
# 198934           2     SB Joshi  ...        NaN           0          0
#
#         total_run_y  non_boundary  isWicketDelivery  player_out    kind  \
# 0                 0             0                 0         NaN     NaN
# 1                 1             0                 0         NaN     NaN
# 2                 1             0                 0         NaN     NaN
# 3                 0             0                 0         NaN     NaN
# 4                 0             0                 0         NaN     NaN
# ...             ...           ...               ...         ...     ...
# 198930            1             0                 0         NaN     NaN
# 198931            1             0                 0         NaN     NaN
# 198932            0             0                 0         NaN     NaN
# 198933            1             0                 0         NaN     NaN
# 198934            0             0                 1    SB Joshi  caught
#
#        fielders_involved                  BattingTeam
# 0                    NaN             Rajasthan Royals
# 1                    NaN             Rajasthan Royals
# 2                    NaN             Rajasthan Royals
# 3                    NaN             Rajasthan Royals
# 4                    NaN             Rajasthan Royals
# ...                  ...                          ...
# 198930               NaN  Royal Challengers Bangalore
# 198931               NaN  Royal Challengers Bangalore
# 198932               NaN  Royal Challengers Bangalore
# 198933               NaN  Royal Challengers Bangalore
# 198934       BB McCullum  Royal Challengers Bangalore
#
# [198935 rows x 22 columns]

# %%
second_innings = second_innings[second_innings['innings']==2]
second_innings.shape
# Out:
# (95974, 22)

# %%
second_innings
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 198930   335982  Bangalore  Kolkata Knight Riders          223
# 198931   335982  Bangalore  Kolkata Knight Riders          223
# 198932   335982  Bangalore  Kolkata Knight Riders          223
# 198933   335982  Bangalore  Kolkata Knight Riders          223
# 198934   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# 121                Rajasthan Royals         Gujarat Titans        2      0
# 122                Rajasthan Royals         Gujarat Titans        2      0
# 123                Rajasthan Royals         Gujarat Titans        2      0
# 124                Rajasthan Royals         Gujarat Titans        2      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber        batter  ... extra_type batsman_run extras_run  \
# 120              1       WP Saha  ...        NaN           0          0
# 121              2       WP Saha  ...        NaN           0          0
# 122              3       WP Saha  ...        NaN           1          0
# 123              4  Shubman Gill  ...        NaN           0          0
# 124              5  Shubman Gill  ...        NaN           0          0
# ...            ...           ...  ...        ...         ...        ...
# 198930           5       P Kumar  ...    legbyes           0          1
# 198931           6      SB Joshi  ...        NaN           1          0
# 198932           7       P Kumar  ...        NaN           0          0
# 198933           1      SB Joshi  ...      wides           0          1
# 198934           2      SB Joshi  ...        NaN           0          0
#
#         total_run_y  non_boundary  isWicketDelivery  player_out    kind  \
# 120               0             0                 0         NaN     NaN
# 121               0             0                 0         NaN     NaN
# 122               1             0                 0         NaN     NaN
# 123               0             0                 0         NaN     NaN
# 124               0             0                 0         NaN     NaN
# ...             ...           ...               ...         ...     ...
# 198930            1             0                 0         NaN     NaN
# 198931            1             0                 0         NaN     NaN
# 198932            0             0                 0         NaN     NaN
# 198933            1             0                 0         NaN     NaN
# 198934            0             0                 1    SB Joshi  caught
#
#        fielders_involved                  BattingTeam
# 120                  NaN               Gujarat Titans
# 121                  NaN               Gujarat Titans
# 122                  NaN               Gujarat Titans
# 123                  NaN               Gujarat Titans
# 124                  NaN               Gujarat Titans
# ...                  ...                          ...
# 198930               NaN  Royal Challengers Bangalore
# 198931               NaN  Royal Challengers Bangalore
# 198932               NaN  Royal Challengers Bangalore
# 198933               NaN  Royal Challengers Bangalore
# 198934       BB McCullum  Royal Challengers Bangalore
#
# [95974 rows x 22 columns]

# %%
second_innings['Team1'] = second_innings['Team1'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['Team2'] = second_innings['Team2'].replace('Delhi Daredevils','Delhi Capitals')

second_innings['Team1'] = second_innings['Team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['Team2'] = second_innings['Team2'].replace('Deccan Chargers','Sunrisers Hyderabad')

second_innings['Team1'] = second_innings['Team1'].replace('Kings XI Punjab','Punjab Kings')
second_innings['Team2'] = second_innings['Team2'].replace('Kings XI Punjab','Punjab Kings')
# Out:
# <ipython-input-22-c59cbae3dde7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team1'] = second_innings['Team1'].replace('Delhi Daredevils','Delhi Capitals')
# <ipython-input-22-c59cbae3dde7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team2'] = second_innings['Team2'].replace('Delhi Daredevils','Delhi Capitals')
# <ipython-input-22-c59cbae3dde7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team1'] = second_innings['Team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
# <ipython-input-22-c59cbae3dde7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team2'] = second_innings['Team2'].replace('Deccan Chargers','Sunrisers Hyderabad')
# <ipython-input-22-c59cbae3dde7>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team1'] = second_innings['Team1'].replace('Kings XI Punjab','Punjab Kings')
# <ipython-input-22-c59cbae3dde7>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team2'] = second_innings['Team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    13277
# Chennai Super Kings            12646
# Delhi Capitals                 12047
# Mumbai Indians                 11898
# Punjab Kings                   11812
# Sunrisers Hyderabad            11708
# Kolkata Knight Riders          11083
# Rajasthan Royals                9745
# Lucknow Super Giants             968
# Gujarat Titans                   790
# Name: count, dtype: int64

# %%
second_innings.columns
# Out:
# Index(['ID', 'City', 'WinningTeam', 'total_run_x', 'Team1', 'Team2', 'innings',
#        'overs', 'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
#        'batsman_run', 'extras_run', 'total_run_y', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'BattingTeam'],
#       dtype='object')

# %%
second_innings.shape
# Out:
# (95974, 22)

# %%
# Function to determine the bowling team
def determine_bowling_team(row):
    if row['BattingTeam'] == row['Team1']:
        return row['Team2']
    else:
        return row['Team1']

# Create the new 'BowlingTeam' column
second_innings['BowlingTeam'] = second_innings.apply(determine_bowling_team, axis=1)
# Out:
# <ipython-input-26-52592b4d233c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings.apply(determine_bowling_team, axis=1)

# %%
second_innings.tail(103)
# Out:
#             ID        City            WinningTeam  total_run_x  \
# 198708  335983  Chandigarh    Chennai Super Kings          241
# 198709  335983  Chandigarh    Chennai Super Kings          241
# 198834  335982   Bangalore  Kolkata Knight Riders          223
# 198835  335982   Bangalore  Kolkata Knight Riders          223
# 198836  335982   Bangalore  Kolkata Knight Riders          223
# ...        ...         ...                    ...          ...
# 198930  335982   Bangalore  Kolkata Knight Riders          223
# 198931  335982   Bangalore  Kolkata Knight Riders          223
# 198932  335982   Bangalore  Kolkata Knight Riders          223
# 198933  335982   Bangalore  Kolkata Knight Riders          223
# 198934  335982   Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 198708                 Punjab Kings    Chennai Super Kings        2     19
# 198709                 Punjab Kings    Chennai Super Kings        2     19
# 198834  Royal Challengers Bangalore  Kolkata Knight Riders        2      0
# 198835  Royal Challengers Bangalore  Kolkata Knight Riders        2      0
# 198836  Royal Challengers Bangalore  Kolkata Knight Riders        2      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber     batter  ... batsman_run extras_run total_run_y  \
# 198708           5  SM Katich  ...           1          0           1
# 198709           6  IK Pathan  ...           0          0           0
# 198834           1   R Dravid  ...           1          0           1
# 198835           2   W Jaffer  ...           0          1           1
# 198836           3   W Jaffer  ...           0          0           0
# ...            ...        ...  ...         ...        ...         ...
# 198930           5    P Kumar  ...           0          1           1
# 198931           6   SB Joshi  ...           1          0           1
# 198932           7    P Kumar  ...           0          0           0
# 198933           1   SB Joshi  ...           0          1           1
# 198934           2   SB Joshi  ...           0          0           0
#
#         non_boundary  isWicketDelivery  player_out    kind  fielders_involved  \
# 198708             0                 0         NaN     NaN                NaN
# 198709             0                 0         NaN     NaN                NaN
# 198834             0                 0         NaN     NaN                NaN
# 198835             0                 0         NaN     NaN                NaN
# 198836             0                 0         NaN     NaN                NaN
# ...              ...               ...         ...     ...                ...
# 198930             0                 0         NaN     NaN                NaN
# 198931             0                 0         NaN     NaN                NaN
# 198932             0                 0         NaN     NaN                NaN
# 198933             0                 0         NaN     NaN                NaN
# 198934             0                 1    SB Joshi  caught        BB McCullum
#
#                         BattingTeam            BowlingTeam
# 198708              Kings XI Punjab           Punjab Kings
# 198709              Kings XI Punjab           Punjab Kings
# 198834  Royal Challengers Bangalore  Kolkata Knight Riders
# 198835  Royal Challengers Bangalore  Kolkata Knight Riders
# 198836  Royal Challengers Bangalore  Kolkata Knight Riders
# ...                             ...                    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders
#
# [103 rows x 23 columns]

# %%
second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Delhi Daredevils','Delhi Capitals')

second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')

second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Kings XI Punjab','Punjab Kings')
second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Kings XI Punjab','Punjab Kings')
# Out:
# <ipython-input-28-420b017f103b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Delhi Daredevils','Delhi Capitals')
# <ipython-input-28-420b017f103b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Delhi Daredevils','Delhi Capitals')
# <ipython-input-28-420b017f103b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')
# <ipython-input-28-420b017f103b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')
# <ipython-input-28-420b017f103b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Kings XI Punjab','Punjab Kings')
# <ipython-input-28-420b017f103b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 198930   335982  Bangalore  Kolkata Knight Riders          223
# 198931   335982  Bangalore  Kolkata Knight Riders          223
# 198932   335982  Bangalore  Kolkata Knight Riders          223
# 198933   335982  Bangalore  Kolkata Knight Riders          223
# 198934   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# 121                Rajasthan Royals         Gujarat Titans        2      0
# 122                Rajasthan Royals         Gujarat Titans        2      0
# 123                Rajasthan Royals         Gujarat Titans        2      0
# 124                Rajasthan Royals         Gujarat Titans        2      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber        batter  ... batsman_run extras_run total_run_y  \
# 120              1       WP Saha  ...           0          0           0
# 121              2       WP Saha  ...           0          0           0
# 122              3       WP Saha  ...           1          0           1
# 123              4  Shubman Gill  ...           0          0           0
# 124              5  Shubman Gill  ...           0          0           0
# ...            ...           ...  ...         ...        ...         ...
# 198930           5       P Kumar  ...           0          1           1
# 198931           6      SB Joshi  ...           1          0           1
# 198932           7       P Kumar  ...           0          0           0
# 198933           1      SB Joshi  ...           0          1           1
# 198934           2      SB Joshi  ...           0          0           0
#
#         non_boundary  isWicketDelivery  player_out    kind  fielders_involved  \
# 120                0                 0         NaN     NaN                NaN
# 121                0                 0         NaN     NaN                NaN
# 122                0                 0         NaN     NaN                NaN
# 123                0                 0         NaN     NaN                NaN
# 124                0                 0         NaN     NaN                NaN
# ...              ...               ...         ...     ...                ...
# 198930             0                 0         NaN     NaN                NaN
# 198931             0                 0         NaN     NaN                NaN
# 198932             0                 0         NaN     NaN                NaN
# 198933             0                 0         NaN     NaN                NaN
# 198934             0                 1    SB Joshi  caught        BB McCullum
#
#                         BattingTeam            BowlingTeam
# 120                  Gujarat Titans       Rajasthan Royals
# 121                  Gujarat Titans       Rajasthan Royals
# 122                  Gujarat Titans       Rajasthan Royals
# 123                  Gujarat Titans       Rajasthan Royals
# 124                  Gujarat Titans       Rajasthan Royals
# ...                             ...                    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders
#
# [95974 rows x 23 columns]

# %%
second_innings['BowlingTeam'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians'], dtype=object)

# %%
# Convert the 'total_run_y' column to numeric, coercing errors
second_innings['total_run_y'] = pd.to_numeric(second_innings['total_run_y'], errors='coerce')

# You might want to handle potential NaN values introduced by coercion
# For example, fill NaN values with 0
second_innings['total_run_y'] = second_innings['total_run_y'].fillna(0)

# Now you can safely apply cumsum()
second_innings['current_Score'] = second_innings.groupby('ID')['total_run_y'].cumsum()
second_innings
# Out:
# <ipython-input-32-dc833fd18596>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['total_run_y'] = pd.to_numeric(second_innings['total_run_y'], errors='coerce')
# <ipython-input-32-dc833fd18596>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['total_run_y'] = second_innings['total_run_y'].fillna(0)
# <ipython-input-32-dc833fd18596>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['current_Score'] = second_innings.groupby('ID')['total_run_y'].cumsum()
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 198930   335982  Bangalore  Kolkata Knight Riders          223
# 198931   335982  Bangalore  Kolkata Knight Riders          223
# 198932   335982  Bangalore  Kolkata Knight Riders          223
# 198933   335982  Bangalore  Kolkata Knight Riders          223
# 198934   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# 121                Rajasthan Royals         Gujarat Titans        2      0
# 122                Rajasthan Royals         Gujarat Titans        2      0
# 123                Rajasthan Royals         Gujarat Titans        2      0
# 124                Rajasthan Royals         Gujarat Titans        2      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber        batter  ... extras_run total_run_y non_boundary  \
# 120              1       WP Saha  ...          0           0            0
# 121              2       WP Saha  ...          0           0            0
# 122              3       WP Saha  ...          0           1            0
# 123              4  Shubman Gill  ...          0           0            0
# 124              5  Shubman Gill  ...          0           0            0
# ...            ...           ...  ...        ...         ...          ...
# 198930           5       P Kumar  ...          1           1            0
# 198931           6      SB Joshi  ...          0           1            0
# 198932           7       P Kumar  ...          0           0            0
# 198933           1      SB Joshi  ...          1           1            0
# 198934           2      SB Joshi  ...          0           0            0
#
#         isWicketDelivery  player_out    kind  fielders_involved  \
# 120                    0         NaN     NaN                NaN
# 121                    0         NaN     NaN                NaN
# 122                    0         NaN     NaN                NaN
# 123                    0         NaN     NaN                NaN
# 124                    0         NaN     NaN                NaN
# ...                  ...         ...     ...                ...
# 198930                 0         NaN     NaN                NaN
# 198931                 0         NaN     NaN                NaN
# 198932                 0         NaN     NaN                NaN
# 198933                 0         NaN     NaN                NaN
# 198934                 1    SB Joshi  caught        BB McCullum
#
#                         BattingTeam            BowlingTeam current_Score
# 120                  Gujarat Titans       Rajasthan Royals             0
# 121                  Gujarat Titans       Rajasthan Royals             0
# 122                  Gujarat Titans       Rajasthan Royals             1
# 123                  Gujarat Titans       Rajasthan Royals             1
# 124                  Gujarat Titans       Rajasthan Royals             1
# ...                             ...                    ...           ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders            80
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders            81
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders            81
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders            82
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders            82
#
# [95974 rows x 24 columns]

# %%
second_innings['runs_left'] = second_innings['total_run_x'] - second_innings['current_Score']
second_innings
# Out:
# <ipython-input-34-b4a2b46e6b9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['runs_left'] = second_innings['total_run_x'] - second_innings['current_Score']
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 198930   335982  Bangalore  Kolkata Knight Riders          223
# 198931   335982  Bangalore  Kolkata Knight Riders          223
# 198932   335982  Bangalore  Kolkata Knight Riders          223
# 198933   335982  Bangalore  Kolkata Knight Riders          223
# 198934   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# 121                Rajasthan Royals         Gujarat Titans        2      0
# 122                Rajasthan Royals         Gujarat Titans        2      0
# 123                Rajasthan Royals         Gujarat Titans        2      0
# 124                Rajasthan Royals         Gujarat Titans        2      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber        batter  ... total_run_y non_boundary  \
# 120              1       WP Saha  ...           0            0
# 121              2       WP Saha  ...           0            0
# 122              3       WP Saha  ...           1            0
# 123              4  Shubman Gill  ...           0            0
# 124              5  Shubman Gill  ...           0            0
# ...            ...           ...  ...         ...          ...
# 198930           5       P Kumar  ...           1            0
# 198931           6      SB Joshi  ...           1            0
# 198932           7       P Kumar  ...           0            0
# 198933           1      SB Joshi  ...           1            0
# 198934           2      SB Joshi  ...           0            0
#
#        isWicketDelivery  player_out    kind  fielders_involved  \
# 120                   0         NaN     NaN                NaN
# 121                   0         NaN     NaN                NaN
# 122                   0         NaN     NaN                NaN
# 123                   0         NaN     NaN                NaN
# 124                   0         NaN     NaN                NaN
# ...                 ...         ...     ...                ...
# 198930                0         NaN     NaN                NaN
# 198931                0         NaN     NaN                NaN
# 198932                0         NaN     NaN                NaN
# 198933                0         NaN     NaN                NaN
# 198934                1    SB Joshi  caught        BB McCullum
#
#                         BattingTeam            BowlingTeam current_Score  \
# 120                  Gujarat Titans       Rajasthan Royals             0
# 121                  Gujarat Titans       Rajasthan Royals             0
# 122                  Gujarat Titans       Rajasthan Royals             1
# 123                  Gujarat Titans       Rajasthan Royals             1
# 124                  Gujarat Titans       Rajasthan Royals             1
# ...                             ...                    ...           ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders            80
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders            81
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders            81
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders            82
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders            82
#
#        runs_left
# 120          131
# 121          131
# 122          130
# 123          130
# 124          130
# ...          ...
# 198930       143
# 198931       142
# 198932       142
# 198933       141
# 198934       141
#
# [95974 rows x 25 columns]

# %%
second_innings['balls_left'] = 126 - (second_innings['overs']*6 +second_innings['ballnumber'])
second_innings
# Out:
# <ipython-input-35-438cfa2a94ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['balls_left'] = 126 - (second_innings['overs']*6 +second_innings['ballnumber'])
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 198930   335982  Bangalore  Kolkata Knight Riders          223
# 198931   335982  Bangalore  Kolkata Knight Riders          223
# 198932   335982  Bangalore  Kolkata Knight Riders          223
# 198933   335982  Bangalore  Kolkata Knight Riders          223
# 198934   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# 121                Rajasthan Royals         Gujarat Titans        2      0
# 122                Rajasthan Royals         Gujarat Titans        2      0
# 123                Rajasthan Royals         Gujarat Titans        2      0
# 124                Rajasthan Royals         Gujarat Titans        2      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber        batter  ... non_boundary isWicketDelivery  \
# 120              1       WP Saha  ...            0                0
# 121              2       WP Saha  ...            0                0
# 122              3       WP Saha  ...            0                0
# 123              4  Shubman Gill  ...            0                0
# 124              5  Shubman Gill  ...            0                0
# ...            ...           ...  ...          ...              ...
# 198930           5       P Kumar  ...            0                0
# 198931           6      SB Joshi  ...            0                0
# 198932           7       P Kumar  ...            0                0
# 198933           1      SB Joshi  ...            0                0
# 198934           2      SB Joshi  ...            0                1
#
#        player_out    kind  fielders_involved                  BattingTeam  \
# 120           NaN     NaN                NaN               Gujarat Titans
# 121           NaN     NaN                NaN               Gujarat Titans
# 122           NaN     NaN                NaN               Gujarat Titans
# 123           NaN     NaN                NaN               Gujarat Titans
# 124           NaN     NaN                NaN               Gujarat Titans
# ...           ...     ...                ...                          ...
# 198930        NaN     NaN                NaN  Royal Challengers Bangalore
# 198931        NaN     NaN                NaN  Royal Challengers Bangalore
# 198932        NaN     NaN                NaN  Royal Challengers Bangalore
# 198933        NaN     NaN                NaN  Royal Challengers Bangalore
# 198934   SB Joshi  caught        BB McCullum  Royal Challengers Bangalore
#
#                   BowlingTeam  current_Score runs_left balls_left
# 120          Rajasthan Royals              0       131        125
# 121          Rajasthan Royals              0       131        124
# 122          Rajasthan Royals              1       130        123
# 123          Rajasthan Royals              1       130        122
# 124          Rajasthan Royals              1       130        121
# ...                       ...            ...       ...        ...
# 198930  Kolkata Knight Riders             80       143         37
# 198931  Kolkata Knight Riders             81       142         36
# 198932  Kolkata Knight Riders             81       142         35
# 198933  Kolkata Knight Riders             82       141         35
# 198934  Kolkata Knight Riders             82       141         34
#
# [95974 rows x 26 columns]

# %%
second_innings.columns
# Out:
# Index(['ID', 'City', 'WinningTeam', 'total_run_x', 'Team1', 'Team2', 'innings',
#        'overs', 'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
#        'batsman_run', 'extras_run', 'total_run_y', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'BattingTeam', 'BowlingTeam', 'current_Score', 'runs_left',
#        'balls_left'],
#       dtype='object')

# %%
# Select the columns of interest
columns_to_check = ['current_Score', 'runs_left', 'balls_left']

# Check how many values in each column are negative
negative_counts = second_innings[columns_to_check].lt(0).sum()

# Display the counts
print("Number of negative values in each column:")
print(negative_counts)
# Out:
# Number of negative values in each column:
# current_Score      0
# runs_left        269
# balls_left         0
# dtype: int64

# %%
# Convert player_out to string first to handle potential mixed types before converting to int
second_innings['player_out'] = second_innings['player_out'].astype(str).fillna("0")
second_innings['player_out'] = second_innings['player_out'].apply(lambda x:x if x=="0" else "1")
# Explicitly convert to int64 to ensure numeric type is recognized by cumsum
second_innings['player_out'] = second_innings['player_out'].astype('int64')

# Now the cumsum operation should work
wickets = second_innings.groupby('ID')['player_out'].cumsum()
second_innings['wickets_remaining'] = 10-wickets
second_innings
# Out:
# <ipython-input-39-52befe2e6145>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_out'] = second_innings['player_out'].astype(str).fillna("0")
# <ipython-input-39-52befe2e6145>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_out'] = second_innings['player_out'].apply(lambda x:x if x=="0" else "1")
# <ipython-input-39-52befe2e6145>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_out'] = second_innings['player_out'].astype('int64')
# <ipython-input-39-52befe2e6145>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['wickets_remaining'] = 10-wickets
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 198930   335982  Bangalore  Kolkata Knight Riders          223
# 198931   335982  Bangalore  Kolkata Knight Riders          223
# 198932   335982  Bangalore  Kolkata Knight Riders          223
# 198933   335982  Bangalore  Kolkata Knight Riders          223
# 198934   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# 121                Rajasthan Royals         Gujarat Titans        2      0
# 122                Rajasthan Royals         Gujarat Titans        2      0
# 123                Rajasthan Royals         Gujarat Titans        2      0
# 124                Rajasthan Royals         Gujarat Titans        2      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber        batter  ... isWicketDelivery player_out    kind  \
# 120              1       WP Saha  ...                0          0     NaN
# 121              2       WP Saha  ...                0          0     NaN
# 122              3       WP Saha  ...                0          0     NaN
# 123              4  Shubman Gill  ...                0          0     NaN
# 124              5  Shubman Gill  ...                0          0     NaN
# ...            ...           ...  ...              ...        ...     ...
# 198930           5       P Kumar  ...                0          0     NaN
# 198931           6      SB Joshi  ...                0          0     NaN
# 198932           7       P Kumar  ...                0          0     NaN
# 198933           1      SB Joshi  ...                0          0     NaN
# 198934           2      SB Joshi  ...                1          1  caught
#
#         fielders_involved                  BattingTeam            BowlingTeam  \
# 120                   NaN               Gujarat Titans       Rajasthan Royals
# 121                   NaN               Gujarat Titans       Rajasthan Royals
# 122                   NaN               Gujarat Titans       Rajasthan Royals
# 123                   NaN               Gujarat Titans       Rajasthan Royals
# 124                   NaN               Gujarat Titans       Rajasthan Royals
# ...                   ...                          ...                    ...
# 198930                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 198931                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 198932                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 198933                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 198934        BB McCullum  Royal Challengers Bangalore  Kolkata Knight Riders
#
#         current_Score  runs_left  balls_left wickets_remaining
# 120                 0        131         125                10
# 121                 0        131         124                10
# 122                 1        130         123                10
# 123                 1        130         122                10
# 124                 1        130         121                10
# ...               ...        ...         ...               ...
# 198930             80        143          37                 1
# 198931             81        142          36                 1
# 198932             81        142          35                 1
# 198933             82        141          35                 1
# 198934             82        141          34                 0
#
# [95974 rows x 27 columns]

# %%
second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
second_innings
# Out:
# <ipython-input-40-ae14c8773a6a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
# <ipython-input-40-ae14c8773a6a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 198930   335982  Bangalore  Kolkata Knight Riders          223
# 198931   335982  Bangalore  Kolkata Knight Riders          223
# 198932   335982  Bangalore  Kolkata Knight Riders          223
# 198933   335982  Bangalore  Kolkata Knight Riders          223
# 198934   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# 121                Rajasthan Royals         Gujarat Titans        2      0
# 122                Rajasthan Royals         Gujarat Titans        2      0
# 123                Rajasthan Royals         Gujarat Titans        2      0
# 124                Rajasthan Royals         Gujarat Titans        2      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber        batter  ...    kind fielders_involved  \
# 120              1       WP Saha  ...     NaN               NaN
# 121              2       WP Saha  ...     NaN               NaN
# 122              3       WP Saha  ...     NaN               NaN
# 123              4  Shubman Gill  ...     NaN               NaN
# 124              5  Shubman Gill  ...     NaN               NaN
# ...            ...           ...  ...     ...               ...
# 198930           5       P Kumar  ...     NaN               NaN
# 198931           6      SB Joshi  ...     NaN               NaN
# 198932           7       P Kumar  ...     NaN               NaN
# 198933           1      SB Joshi  ...     NaN               NaN
# 198934           2      SB Joshi  ...  caught       BB McCullum
#
#                         BattingTeam            BowlingTeam  current_Score  \
# 120                  Gujarat Titans       Rajasthan Royals              0
# 121                  Gujarat Titans       Rajasthan Royals              0
# 122                  Gujarat Titans       Rajasthan Royals              1
# 123                  Gujarat Titans       Rajasthan Royals              1
# 124                  Gujarat Titans       Rajasthan Royals              1
# ...                             ...                    ...            ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders             80
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders             81
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders             81
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders             82
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders             82
#
#         runs_left  balls_left  wickets_remaining   crr    rrr
# 120           131         125                 10 -0.00   6.29
# 121           131         124                 10 -0.00   6.34
# 122           130         123                 10 -2.00   6.34
# 123           130         122                 10 -3.00   6.39
# 124           130         121                 10 -6.00   6.45
# ...           ...         ...                ...   ...    ...
# 198930        143          37                  1  5.78  23.19
# 198931        142          36                  1  5.79  23.67
# 198932        142          35                  1  5.72  24.34
# 198933        141          35                  1  5.79  24.17
# 198934        141          34                  0  5.72  24.88
#
# [95974 rows x 29 columns]

# %%
def winner(team):
    return 1 if team['BattingTeam'] == team['WinningTeam'] else 0
second_innings['results'] = second_innings.apply(winner,axis=1)
second_innings
# Out:
# <ipython-input-41-532891755fd7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['results'] = second_innings.apply(winner,axis=1)
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 198930   335982  Bangalore  Kolkata Knight Riders          223
# 198931   335982  Bangalore  Kolkata Knight Riders          223
# 198932   335982  Bangalore  Kolkata Knight Riders          223
# 198933   335982  Bangalore  Kolkata Knight Riders          223
# 198934   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# 121                Rajasthan Royals         Gujarat Titans        2      0
# 122                Rajasthan Royals         Gujarat Titans        2      0
# 123                Rajasthan Royals         Gujarat Titans        2      0
# 124                Rajasthan Royals         Gujarat Titans        2      0
# ...                             ...                    ...      ...    ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber        batter  ... fielders_involved  \
# 120              1       WP Saha  ...               NaN
# 121              2       WP Saha  ...               NaN
# 122              3       WP Saha  ...               NaN
# 123              4  Shubman Gill  ...               NaN
# 124              5  Shubman Gill  ...               NaN
# ...            ...           ...  ...               ...
# 198930           5       P Kumar  ...               NaN
# 198931           6      SB Joshi  ...               NaN
# 198932           7       P Kumar  ...               NaN
# 198933           1      SB Joshi  ...               NaN
# 198934           2      SB Joshi  ...       BB McCullum
#
#                         BattingTeam            BowlingTeam  current_Score  \
# 120                  Gujarat Titans       Rajasthan Royals              0
# 121                  Gujarat Titans       Rajasthan Royals              0
# 122                  Gujarat Titans       Rajasthan Royals              1
# 123                  Gujarat Titans       Rajasthan Royals              1
# 124                  Gujarat Titans       Rajasthan Royals              1
# ...                             ...                    ...            ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders             80
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders             81
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders             81
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders             82
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders             82
#
#         runs_left  balls_left  wickets_remaining   crr    rrr results
# 120           131         125                 10 -0.00   6.29       1
# 121           131         124                 10 -0.00   6.34       1
# 122           130         123                 10 -2.00   6.34       1
# 123           130         122                 10 -3.00   6.39       1
# 124           130         121                 10 -6.00   6.45       1
# ...           ...         ...                ...   ...    ...     ...
# 198930        143          37                  1  5.78  23.19       0
# 198931        142          36                  1  5.79  23.67       0
# 198932        142          35                  1  5.72  24.34       0
# 198933        141          35                  1  5.79  24.17       0
# 198934        141          34                  0  5.72  24.88       0
#
# [95974 rows x 30 columns]

# %%
required_data = second_innings[['BattingTeam','BowlingTeam','City','runs_left','balls_left','wickets_remaining','total_run_x','crr','rrr','results']]
required_data
# Out:
#                         BattingTeam            BowlingTeam       City  \
# 120                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 121                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 122                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 123                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 124                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                             ...                    ...        ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#         runs_left  balls_left  wickets_remaining  total_run_x   crr    rrr  \
# 120           131         125                 10          131 -0.00   6.29
# 121           131         124                 10          131 -0.00   6.34
# 122           130         123                 10          131 -2.00   6.34
# 123           130         122                 10          131 -3.00   6.39
# 124           130         121                 10          131 -6.00   6.45
# ...           ...         ...                ...          ...   ...    ...
# 198930        143          37                  1          223  5.78  23.19
# 198931        142          36                  1          223  5.79  23.67
# 198932        142          35                  1          223  5.72  24.34
# 198933        141          35                  1          223  5.79  24.17
# 198934        141          34                  0          223  5.72  24.88
#
#         results
# 120           1
# 121           1
# 122           1
# 123           1
# 124           1
# ...         ...
# 198930        0
# 198931        0
# 198932        0
# 198933        0
# 198934        0
#
# [95974 rows x 10 columns]

# %%
required_data = required_data.replace([np.inf, -np.inf], np.nan)
required_data = required_data.dropna()
required_data = required_data[required_data['crr'] >= 0]
columns_to_check = ['runs_left', 'balls_left', 'wickets_remaining', 'total_run_x', 'crr', 'rrr', 'results']

required_data = required_data[~(required_data[columns_to_check] < 0).any(axis=1)]
required_data.head()
# Out:
#         BattingTeam       BowlingTeam       City  runs_left  balls_left  \
# 120  Gujarat Titans  Rajasthan Royals  Ahmedabad        131         125
# 121  Gujarat Titans  Rajasthan Royals  Ahmedabad        131         124
# 126  Gujarat Titans  Rajasthan Royals  Ahmedabad        126         119
# 127  Gujarat Titans  Rajasthan Royals  Ahmedabad        122         118
# 128  Gujarat Titans  Rajasthan Royals  Ahmedabad        122         117
#
#      wickets_remaining  total_run_x   crr   rrr  results
# 120                 10          131  -0.0  6.29        1
# 121                 10          131  -0.0  6.34        1
# 126                 10          131  30.0  6.35        1
# 127                 10          131  27.0  6.20        1
# 128                 10          131  18.0  6.26        1

# %%
required_data.rename(columns={'BattingTeam': 'batting_team', 'BowlingTeam': 'bowling_team', 'City': 'city'}, inplace=True)
required_data
# Out:
#                        batting_team           bowling_team       city  \
# 120                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 121                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 126                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 127                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 128                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                             ...                    ...        ...
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#         runs_left  balls_left  wickets_remaining  total_run_x    crr    rrr  \
# 120           131         125                 10          131  -0.00   6.29
# 121           131         124                 10          131  -0.00   6.34
# 126           126         119                 10          131  30.00   6.35
# 127           122         118                 10          131  27.00   6.20
# 128           122         117                 10          131  18.00   6.26
# ...           ...         ...                ...          ...    ...    ...
# 198930        143          37                  1          223   5.78  23.19
# 198931        142          36                  1          223   5.79  23.67
# 198932        142          35                  1          223   5.72  24.34
# 198933        141          35                  1          223   5.79  24.17
# 198934        141          34                  0          223   5.72  24.88
#
#         results
# 120           1
# 121           1
# 126           1
# 127           1
# 128           1
# ...         ...
# 198930        0
# 198931        0
# 198932        0
# 198933        0
# 198934        0
#
# [85973 rows x 10 columns]

# %%
numeric = required_data[['runs_left', 'balls_left', 'wickets_remaining', 'total_run_x', 'crr', 'rrr', 'results']]
has_infinite_values = np.any(np.isinf(numeric))

has_negative_values = (numeric < 0).any().any()

has_null_values = numeric.isnull().any().any()

print(f"Has Infinite Values: {has_infinite_values}")
print(f"Has Negative Values: {has_negative_values}")
print(f"Has Null Values: {has_null_values}")
# Out:
# Has Infinite Values: False
# Has Negative Values: False
# Has Null Values: False

# %%
required_data.to_csv("csv2008-22.csv", index=False)

# %%
from sklearn.model_selection import train_test_split

x = required_data.iloc[:, :-1]
y = required_data.iloc[:,-1]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=100)
x_train.head()
# Out:
#                        batting_team                 bowling_team       city  \
# 95642   Royal Challengers Bangalore          Chennai Super Kings    Chennai
# 127867          Chennai Super Kings        Kolkata Knight Riders    Kolkata
# 98243                  Punjab Kings          Chennai Super Kings    Chennai
# 37978              Rajasthan Royals          Chennai Super Kings  Abu Dhabi
# 9346            Sunrisers Hyderabad  Royal Challengers Bangalore     Mumbai
#
#         runs_left  balls_left  wickets_remaining  total_run_x    crr   rrr
# 95642          99          82                  7          149   7.89  7.24
# 127867         66          58                  7          120   5.23  6.83
# 98243         185         117                  9          193  16.00  9.49
# 37978          10          29                  7          126   7.65  2.07
# 9346           67         118                 10           69   6.00  3.41

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])
],
remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8277193635433144

# %%
pipe.predict_proba(x_test)[0]
# Out:
# array([0.005314, 0.994686])

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
from sklearn.ensemble import RandomForestClassifier

ra_pipe = Pipeline([
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

ra_pipe.fit(x_train,y_train)

ra_y_pred = ra_pipe.predict(x_test)

accuracy_score(y_test,ra_y_pred)
# Out:
# 0.9989299339350517

# %%
import pickle
pickle.dump(ra_pipe,open('ra_pipe.pkl','wb'))

# %%
teams
# Out:
# ['Kolkata Knight Riders',
#  'Chennai Super Kings',
#  'Punjab Kings',
#  'Rajasthan Royals',
#  'Mumbai Indians',
#  'Delhi Capitals',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad',
#  'Lucknow Super Giants',
#  'Gujarat Titans']

# %%
required_data['city'].unique()
# Out:
# array(['Ahmedabad', 'Kolkata', 'Mumbai', 'Navi Mumbai', 'Pune', 'Dubai',
#        'Sharjah', 'Abu Dhabi', 'Delhi', 'Chennai', 'Hyderabad',
#        'Visakhapatnam', 'Chandigarh', 'Bengaluru', 'Jaipur', 'Indore',
#        'Bangalore', 'Raipur', 'Ranchi', 'Cuttack', 'Dharamsala', 'Nagpur',
#        'Johannesburg', 'Centurion', 'Durban', 'Bloemfontein',
#        'Port Elizabeth', 'Kimberley', 'East London', 'Cape Town'],
#       dtype=object)

# %%
required_data.head(2)
# Out:
#        batting_team      bowling_team       city  runs_left  balls_left  \
# 120  Gujarat Titans  Rajasthan Royals  Ahmedabad        131         125
# 121  Gujarat Titans  Rajasthan Royals  Ahmedabad        131         124
#
#      wickets_remaining  total_run_x  crr   rrr  results
# 120                 10          131 -0.0  6.29        1
# 121                 10          131 -0.0  6.34        1

# %%
data = pd.read_csv('csv2023.csv')
data.rename(columns={'max_total_run_x': 'total_run_x'}, inplace=True)
data.head(2)

# %%
df = pd.concat([required_data, data], ignore_index=True)
df

# %%
x = df.iloc[:, :-1]
y = df.iloc[:,-1]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=100)
x_train.head()

# %%
from sklearn.ensemble import RandomForestClassifier

ra_pipe = Pipeline([
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

ra_pipe.fit(x_train,y_train)

ra_y_pred = ra_pipe.predict(x_test)

accuracy_score(y_test,ra_y_pred)

# %%
import pickle
pickle.dump(ra_pipe,open('ra_pipe.pkl','wb'))
